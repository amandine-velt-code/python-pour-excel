# %% [markdown]
# 🛠️ 00 — Installation et vérification de votre environnement
# Ce notebook teste automatiquement si votre installation Python est prête pour le livre *Python pour Excel* - Amandine Velt

# %% [markdown]
# ## Test 1 — Version de Python

# %%
import sys
print(sys.version)
# Out:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# ## Test 2 — pandas

# %%
import pandas as pd
print('pandas OK — version :', pd.__version__)
# Out:
# pandas OK — version : 2.2.3

# %% [markdown]
# ## Test 3 — openpyxl

# %%
import openpyxl
print('openpyxl OK — version :', openpyxl.__version__)
# Out:
# openpyxl OK — version : 3.1.5

# %% [markdown]
# ## Test 4 — XlsxWriter

# %%
import xlsxwriter
print('XlsxWriter OK — version :', xlsxwriter.__version__)
# Out:
# XlsxWriter OK — version : 3.2.9

# %% [markdown]
# ## Test 5 — xlwings (optionnel mais utile)

# %%
try:
    import xlwings as xw
    print('xlwings OK — version :', xw.__version__)
except Exception:
    print('xlwings non disponible (normal si vous n’êtes pas sous Windows/Mac)')
# Out:
# xlwings OK — version : 0.32.1

# %% [markdown]
# Si tout est OK et qu’aucune erreur n’apparaît, alors vous êtes prêt ! C’est parti !
